# %%
# !pip install minatar
# !pip install dm-haiku
# !pip install distrax
# !pip install pgx
# !pip install omegaconf
# !pip install learn2learn
# Out:
# Requirement already satisfied: minatar in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (1.0.15)
# Requirement already satisfied: cycler>=0.10.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (1.4.7)
# Requirement already satisfied: matplotlib>=3.0.3 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (3.7.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (2.2.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (2024.2)
# Requirement already satisfied: scipy>=1.2.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (1.13.1)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (0.13.2)
# Requirement already satisfied: six>=1.12.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from minatar) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.3->minatar) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.3->minatar) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.3->minatar) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.3->minatar) (11.0.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.3->minatar) (6.4.5)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->minatar) (2024.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.3->minatar) (3.20.2)
# Requirement already satisfied: dm-haiku in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (0.0.13)
# Requirement already satisfied: absl-py>=0.7.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from dm-haiku) (2.1.0)
# Requirement already satisfied: jmp>=0.0.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from dm-haiku) (0.0.4)
# Requirement already satisfied: numpy>=1.18.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from dm-haiku) (1.24.3)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from dm-haiku) (0.9.0)
# Requirement already satisfied: distrax in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (0.1.5)
# Requirement already satisfied: absl-py>=0.9.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (2.1.0)
# Requirement already satisfied: chex>=0.1.8 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (0.1.87)
# Requirement already satisfied: jax>=0.1.55 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (0.4.30)
# Requirement already satisfied: jaxlib>=0.1.67 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (0.4.30)
# Requirement already satisfied: numpy>=1.23.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (1.24.3)
# Requirement already satisfied: tensorflow-probability>=0.15.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from distrax) (0.25.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from chex>=0.1.8->distrax) (4.12.2)
# Requirement already satisfied: toolz>=0.9.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from chex>=0.1.8->distrax) (1.0.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.1.55->distrax) (0.5.0)
# Requirement already satisfied: opt-einsum in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.1.55->distrax) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.1.55->distrax) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.1.55->distrax) (8.5.0)
# Requirement already satisfied: six>=1.10.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from tensorflow-probability>=0.15.0->distrax) (1.16.0)
# Requirement already satisfied: decorator in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from tensorflow-probability>=0.15.0->distrax) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from tensorflow-probability>=0.15.0->distrax) (3.1.0)
# Requirement already satisfied: gast>=0.3.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from tensorflow-probability>=0.15.0->distrax) (0.4.0)
# Requirement already satisfied: dm-tree in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from tensorflow-probability>=0.15.0->distrax) (0.1.8)
# Requirement already satisfied: zipp>=3.20 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.1.55->distrax) (3.20.2)
# Requirement already satisfied: pgx in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: jax>=0.4.6 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from pgx) (0.4.30)
# Requirement already satisfied: typing_extensions>=4.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from pgx) (4.12.2)
# Requirement already satisfied: svgwrite in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from pgx) (1.4.3)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (0.5.0)
# Requirement already satisfied: numpy>=1.22 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (1.24.3)
# Requirement already satisfied: opt-einsum in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jax>=0.4.6->pgx) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.4.6->pgx) (3.20.2)
# Requirement already satisfied: omegaconf in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from omegaconf) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from omegaconf) (6.0.2)
# Requirement already satisfied: learn2learn in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (1.24.3)
# Requirement already satisfied: gym>=0.14.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (0.26.2)
# Requirement already satisfied: torch>=1.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (2.5.1)
# Requirement already satisfied: torchvision>=0.3.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (0.20.1)
# Requirement already satisfied: scipy in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (1.13.1)
# Requirement already satisfied: requests in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (2.32.3)
# Requirement already satisfied: gsutil in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (5.32)
# Requirement already satisfied: tqdm in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (4.65.0)
# Requirement already satisfied: qpth>=0.0.15 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from learn2learn) (0.0.18)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gym>=0.14.0->learn2learn) (3.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gym>=0.14.0->learn2learn) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gym>=0.14.0->learn2learn) (8.5.0)
# Requirement already satisfied: cvxpy>=1.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from qpth>=0.0.15->learn2learn) (1.6.0)
# Requirement already satisfied: filelock in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (4.12.2)
# Requirement already satisfied: networkx in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (3.1.4)
# Requirement already satisfied: fsspec in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torch>=1.1.0->learn2learn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.1.0->learn2learn) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from torchvision>=0.3.0->learn2learn) (11.0.0)
# Requirement already satisfied: argcomplete>=3.5.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (3.5.2)
# Requirement already satisfied: crcmod>=1.7 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (1.7)
# Requirement already satisfied: fasteners>=0.14.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (0.19)
# Requirement already satisfied: gcs-oauth2-boto-plugin>=3.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (3.2)
# Requirement already satisfied: google-apitools>=0.5.32 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (0.5.32)
# Requirement already satisfied: httplib2==0.20.4 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (0.20.4)
# Requirement already satisfied: google-reauth>=0.1.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (0.1.1)
# Requirement already satisfied: monotonic>=1.4 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (1.6)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=0.13 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (24.2.1)
# Requirement already satisfied: retry-decorator>=1.0.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (1.1.1)
# Requirement already satisfied: six>=1.16.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (1.16.0)
# Requirement already satisfied: google-auth==2.17.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (2.17.0)
# Requirement already satisfied: google-auth-httplib2>=0.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gsutil->learn2learn) (0.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-auth==2.17.0->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-auth==2.17.0->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-auth==2.17.0->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (4.7.2)
# Requirement already satisfied: aiohttp<4.0.0dev,>=3.6.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (3.11.10)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from httplib2==0.20.4->gsutil->learn2learn) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from requests->learn2learn) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from requests->learn2learn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from requests->learn2learn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from requests->learn2learn) (2024.8.30)
# Requirement already satisfied: osqp>=0.6.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn) (0.9.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from cvxpy>=1.1.0->qpth>=0.0.15->learn2learn) (3.2.7)
# Requirement already satisfied: boto>=2.29.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gcs-oauth2-boto-plugin>=3.2->gsutil->learn2learn) (2.49.0)
# Requirement already satisfied: oauth2client>=2.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from gcs-oauth2-boto-plugin>=3.2->gsutil->learn2learn) (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth==2.17.0->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (0.6.1)
# Requirement already satisfied: pyu2f in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from google-reauth>=0.1.0->gsutil->learn2learn) (0.1.5)
# Requirement already satisfied: zipp>=3.20 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gym>=0.14.0->learn2learn) (3.20.2)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from pyOpenSSL<=24.2.1,>=0.13->gsutil->learn2learn) (43.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.1.0->learn2learn) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]==2.17.0->gsutil->learn2learn) (1.18.3)
# Requirement already satisfied: cffi>=1.12 in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from cryptography<44,>=41.0.5->pyOpenSSL<=24.2.1,>=0.13->gsutil->learn2learn) (1.17.1)
# Requirement already satisfied: qdldl in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from osqp>=0.6.2->cvxpy>=1.1.0->qpth>=0.0.15->learn2learn) (0.1.7.post4)
# Requirement already satisfied: pycparser in /Users/alfiovavassori/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL<=24.2.1,>=0.13->gsutil->learn2learn) (2.22)

# %%
import sys
import jax
import jax.numpy as jnp
import haiku as hk
import optax
from typing import NamedTuple, Literal
import distrax
import pgx
from pgx.experimental import auto_reset
import time

import pickle
from omegaconf import OmegaConf
from pydantic import BaseModel
import wandb
import learn2learn as l2l
import jax
import jax.numpy as jnp
import flax.linen as nn
import numpy as np
import optax
from flax.linen.initializers import constant, orthogonal
from typing import Sequence, NamedTuple, Any
from flax.training.train_state import TrainState
import distrax
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 import jax
#       3 import jax.numpy as jnp
# ----> 4 import haiku as hk
#       5 import optax
#       6 from typing import NamedTuple, Literal
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/haiku/__init__.py:20
#      18 from haiku import config
#      19 from haiku import data_structures
# ---> 20 from haiku import experimental
#      21 from haiku import initializers
#      22 from haiku import mixed_precision
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/haiku/experimental/__init__.py:59
#      57 # pylint: disable=g-import-not-at-top,g-bad-import-order
#      58 try:
# ---> 59   from haiku.experimental import flax
#      60 except ImportError:
#      61   # We inject a shim module to provide helpful errors when flax isn't installed.
#      62   from haiku._src import no_flax
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/haiku/experimental/flax.py:18
#       1 # Copyright 2023 DeepMind Technologies Limited. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      14 # ==============================================================================
#      15 # pylint: disable=g-importing-member
#      16 """Tools for working with Haiku and Flax."""
# ---> 18 from haiku._src.flax.flax_module import Module
#      19 from haiku._src.flax.transform_flax import lift
#      20 from haiku._src.flax.utils import flatten_flax_to_haiku
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/haiku/_src/flax/flax_module.py:20
#      16 """Utilities for converting Haiku modules to Flax modules."""
#      18 from typing import TypeVar, Union
# ---> 20 import flax.core
#      21 import flax.linen as nn
#      22 from haiku._src import filtering
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/flax/__init__.py:18
#       1 # Copyright 2023 The Flax Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      16 """Flax API."""
# ---> 18 from .configurations import (
#      19     config as config,
#      20 )
#      22 from . import core
#      23 from . import jax_utils
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/flax/configurations.py:92
#      87 # Flax Global Configuration Variables:
#      88
#      89 # Whether to use the lazy rng implementation.
#      90 flax_lazy_rng = static_bool_env('FLAX_LAZY_RNG', True)
# ---> 92 flax_filter_frames = define_bool_state(
#      93     name='filter_frames',
#      94     default=True,
#      95     help=('Whether to hide flax-internal stack frames from tracebacks.'))
#      97 flax_profile = define_bool_state(
#      98     name='profile',
#      99     default=True,
#     100     help=('Whether to run Module methods under jax.named_scope for profiles.'))
#     102 flax_use_orbax_checkpointing = define_bool_state(
#     103     name='use_orbax_checkpointing',
#     104     default=True,
#     105     help=('Whether to use Orbax to save checkpoints.'))
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/USI/Master/3rd Semester/Advanced Topics in Machine Learning/Project 1/.venv/lib/python3.9/site-packages/flax/configurations.py:42, in define_bool_state(name, default, help)
#      35 def define_bool_state(name, default, help):
#      36   """Set up a boolean flag using JAX's config system.
#      37
#      38   The flag will actually be stored as an environment variable of
#      39   'FLAX_<UPPERCASE_NAME>'. JAX config ensures that the flag can be overwritten
#      40   on runtime with `flax.config.update('flax_<config_name>', <value>)`.
#      41   """
# ---> 42   return jax_config.define_bool_state('flax_' + name, default, help)
#
# AttributeError: 'Config' object has no attribute 'define_bool_state'

# %%
# Configuration class remains unchanged
class PPOConfig(BaseModel):
    env_name: Literal[
        "minatar-breakout",
        "minatar-freeway",
        "minatar-space_invaders",
        "minatar-asterix",
        "minatar-seaquest",
    ] = "minatar-space_invaders" 
    seed: int = 0
    lr: float = 1e-3
    num_envs: int = 64 
    num_eval_envs: int = 100
    num_steps: int = 128
    total_timesteps: int = int(1e7)
    update_epochs: int = 4
    minibatch_size: int = 4096
    gamma: float = 0.99
    gae_lambda: float = 0.95
    clip_eps: float = 0.2
    ent_coef: float = 0.01
    vf_coef: float = 0.5
    max_grad_norm: float = 0.5
    wandb_entity: str = "alfiovavassori-universit-della-svizzera-italiana-org" 
    wandb_project: str = "pgx-minatar-ppo"  
    save_model: bool = False

    class Config:
        extra = "forbid"

args = PPOConfig()

# Initialize the environment
env = pgx.make(str(args.env_name))

num_updates = args.total_timesteps // args.num_envs // args.num_steps
num_minibatches = args.num_envs * args.num_steps // args.minibatch_size

# Actor-Critic model definition
class ActorCritic(hk.Module):
    def __init__(self, num_actions, activation="tanh"):
        super().__init__()
        self.num_actions = num_actions
        self.activation = activation
        assert activation in ["relu", "tanh"]

    def __call__(self, x):
        x = x.astype(jnp.float32)
        if self.activation == "relu":
            activation = jax.nn.relu
        else:
            activation = jax.nn.tanh
        x = hk.Conv2D(32, kernel_shape=2)(x)
        x = jax.nn.relu(x)
        x = hk.avg_pool(x, window_shape=(2, 2),
                        strides=(2, 2), padding="VALID")
        x = x.reshape((x.shape[0], -1))  # flatten
        x = hk.Linear(64)(x)
        x = jax.nn.relu(x)
        actor_mean = hk.Linear(64)(x)
        actor_mean = activation(actor_mean)
        actor_mean = hk.Linear(64)(actor_mean)
        actor_mean = activation(actor_mean)
        actor_mean = hk.Linear(self.num_actions)(actor_mean)

        critic = hk.Linear(64)(x)
        critic = activation(critic)
        critic = hk.Linear(64)(critic)
        critic = activation(critic)
        critic = hk.Linear(1)(critic)

        return actor_mean, jnp.squeeze(critic, axis=-1)


def forward_fn(x, is_eval=False):
    net = ActorCritic(env.num_actions, activation="tanh")
    logits, value = net(x)
    return logits, value


forward = hk.without_apply_rng(hk.transform(forward_fn))


optimizer = optax.chain(optax.clip_by_global_norm(
    args.max_grad_norm), optax.adam(args.lr, eps=1e-5))


class Transition(NamedTuple):
    done: jnp.ndarray
    action: jnp.ndarray
    value: jnp.ndarray
    reward: jnp.ndarray
    log_prob: jnp.ndarray
    obs: jnp.ndarray


def make_update_fn():
    # TRAIN LOOP
    def _update_step(runner_state):
        # COLLECT TRAJECTORIES
        step_fn = jax.vmap(auto_reset(env.step, env.init))

        def _env_step(runner_state, unused):
            params, opt_state, env_state, last_obs, rng = runner_state
            # SELECT ACTION
            rng, _rng = jax.random.split(rng)
            logits, value = forward.apply(params, last_obs)
            pi = distrax.Categorical(logits=logits)
            action = pi.sample(seed=_rng)
            log_prob = pi.log_prob(action)

            # STEP ENV
            rng, _rng = jax.random.split(rng)
            keys = jax.random.split(_rng, env_state.observation.shape[0])
            env_state = step_fn(env_state, action, keys)
            transition = Transition(
                env_state.terminated,
                action,
                value,
                jnp.squeeze(env_state.rewards),
                log_prob,
                last_obs
            )
            runner_state = (params, opt_state, env_state,
                            env_state.observation, rng)
            return runner_state, transition

        runner_state, traj_batch = jax.lax.scan(
            _env_step, runner_state, None, args.num_steps
        )

        # CALCULATE ADVANTAGE
        params, opt_state, env_state, last_obs, rng = runner_state
        _, last_val = forward.apply(params, last_obs)

        def _calculate_gae(traj_batch, last_val):
            def _get_advantages(gae_and_next_value, transition):
                gae, next_value = gae_and_next_value
                done, value, reward = (
                    transition.done,
                    transition.value,
                    transition.reward,
                )
                delta = reward + args.gamma * next_value * (1 - done) - value
                gae = (
                    delta
                    + args.gamma * args.gae_lambda * (1 - done) * gae
                )
                return (gae, value), gae

            _, advantages = jax.lax.scan(
                _get_advantages,
                (jnp.zeros_like(last_val), last_val),
                traj_batch,
                reverse=True,
                unroll=16,
            )
            return advantages, advantages + traj_batch.value

        advantages, targets = _calculate_gae(traj_batch, last_val)

        # UPDATE NETWORK
        def _update_epoch(update_state, unused):
            def _update_minbatch(tup, batch_info):
                params, opt_state = tup
                traj_batch, advantages, targets = batch_info

                def _loss_fn(params, traj_batch, gae, targets):
                    # RERUN NETWORK
                    logits, value = forward.apply(params, traj_batch.obs)
                    pi = distrax.Categorical(logits=logits)
                    log_prob = pi.log_prob(traj_batch.action)

                    # CALCULATE VALUE LOSS
                    value_pred_clipped = traj_batch.value + (
                        value - traj_batch.value
                    ).clip(-args.clip_eps, args.clip_eps)
                    value_losses = jnp.square(value - targets)
                    value_losses_clipped = jnp.square(
                        value_pred_clipped - targets)
                    value_loss = (
                        0.5 * jnp.maximum(value_losses,
                                          value_losses_clipped).mean()
                    )

                    # CALCULATE ACTOR LOSS
                    ratio = jnp.exp(log_prob - traj_batch.log_prob)
                    gae = (gae - gae.mean()) / (gae.std() + 1e-8)
                    loss_actor1 = ratio * gae
                    loss_actor2 = (
                        jnp.clip(
                            ratio,
                            1.0 - args.clip_eps,
                            1.0 + args.clip_eps,
                        )
                        * gae
                    )
                    loss_actor = -jnp.minimum(loss_actor1, loss_actor2)
                    loss_actor = loss_actor.mean()
                    entropy = pi.entropy().mean()

                    total_loss = (
                        loss_actor
                        + args.vf_coef * value_loss
                        - args.ent_coef * entropy
                    )
                    return total_loss, (value_loss, loss_actor, entropy)

                grad_fn = jax.value_and_grad(_loss_fn, has_aux=True)
                total_loss, grads = grad_fn(
                    params, traj_batch, advantages, targets)
                updates, opt_state = optimizer.update(grads, opt_state)
                params = optax.apply_updates(params, updates)
                return (params, opt_state), total_loss

            params, opt_state, traj_batch, advantages, targets, rng = update_state
            rng, _rng = jax.random.split(rng)
            batch_size = args.minibatch_size * num_minibatches
            assert (
                batch_size == args.num_steps * args.num_envs
            ), "batch size must be equal to number of steps * number of envs"
            permutation = jax.random.permutation(_rng, batch_size)
            batch = (traj_batch, advantages, targets)
            batch = jax.tree_util.tree_map(
                lambda x: x.reshape((batch_size,) + x.shape[2:]), batch
            )
            shuffled_batch = jax.tree_util.tree_map(
                lambda x: jnp.take(x, permutation, axis=0), batch
            )
            minibatches = jax.tree_util.tree_map(
                lambda x: jnp.reshape(
                    x, [num_minibatches, -1] + list(x.shape[1:])
                ),
                shuffled_batch,
            )
            (params, opt_state),  total_loss = jax.lax.scan(
                _update_minbatch, (params, opt_state), minibatches
            )
            update_state = (params, opt_state, traj_batch,
                            advantages, targets, rng)
            return update_state, total_loss

        update_state = (params, opt_state, traj_batch,
                        advantages, targets, rng)
        update_state, loss_info = jax.lax.scan(
            _update_epoch, update_state, None, args.update_epochs
        )
        params, opt_state, _, _, _, rng = update_state

        runner_state = (params, opt_state, env_state, last_obs, rng)
        return runner_state, loss_info
    return _update_step


@jax.jit
def evaluate(params, rng_key):
    step_fn = jax.vmap(env.step)
    rng_key, sub_key = jax.random.split(rng_key)
    subkeys = jax.random.split(sub_key, args.num_eval_envs)
    state = jax.vmap(env.init)(subkeys)
    R = jnp.zeros_like(state.rewards)

    def cond_fn(tup):
        state, _, _ = tup
        return ~state.terminated.all()

    def loop_fn(tup):
        state, R, rng_key = tup
        logits, value = forward.apply(params, state.observation)
        # action = logits.argmax(axis=-1)
        pi = distrax.Categorical(logits=logits)
        rng_key, _rng = jax.random.split(rng_key)
        action = pi.sample(seed=_rng)
        rng_key, _rng = jax.random.split(rng_key)
        keys = jax.random.split(_rng, state.observation.shape[0])
        state = step_fn(state, action, keys)
        return state, R + state.rewards, rng_key
    state, R, _ = jax.lax.while_loop(cond_fn, loop_fn, (state, R, rng_key))
    return R.mean()


def train(rng):
    tt = 0
    st = time.time()
    # INIT NETWORK
    rng, _rng = jax.random.split(rng)
    init_x = jnp.zeros((1, ) + env.observation_shape)
    params = forward.init(_rng, init_x)
    opt_state = optimizer.init(params=params)

    # INIT UPDATE FUNCTION
    _update_step = make_update_fn()
    jitted_update_step = jax.jit(_update_step)

    # INIT ENV
    rng, _rng = jax.random.split(rng)
    reset_rng = jax.random.split(_rng, args.num_envs)
    env_state = jax.jit(jax.vmap(env.init))(reset_rng)

    rng, _rng = jax.random.split(rng)
    runner_state = (params, opt_state, env_state, env_state.observation, _rng)

    # warm up
    _, _ = jitted_update_step(runner_state)

    steps = 0

    # initial evaluation
    et = time.time()  # exclude evaluation time
    tt += et - st
    rng, _rng = jax.random.split(rng)
    eval_R = evaluate(runner_state[0], _rng)
    log = {"sec": tt, f"{args.env_name}/eval_R": float(eval_R), "steps": steps}
    print(log)
    wandb.log(log)
    st = time.time()

    for i in range(num_updates):
        runner_state, loss_info = jitted_update_step(runner_state)
        steps += args.num_envs * args.num_steps

        # evaluation
        et = time.time()  # exclude evaluation time
        tt += et - st
        rng, _rng = jax.random.split(rng)
        eval_R = evaluate(runner_state[0], _rng)
        log = {"sec": tt, f"{args.env_name}/eval_R": float(eval_R), "steps": steps}
        print(log)
        wandb.log(log)
        st = time.time()

    return runner_state

if __name__ == "__main__":
    wandb.init(project=args.wandb_project, entity=args.wandb_entity, config=args.dict())
    rng = jax.random.PRNGKey(args.seed)
    out = train(rng)
    if args.save_model:
        with open(f"{args.env_name}-seed={args.seed}.ckpt", "wb") as f:
            pickle.dump(out[0], f)
# Out:
# env_name='minatar-space_invaders' seed=0 lr=0.001 num_envs=64 num_eval_envs=100 num_steps=128 total_timesteps=10000000 update_epochs=4 minibatch_size=4096 gamma=0.99 gae_lambda=0.9 clip_eps=0.25 ent_coef=0.005 vf_coef=0.5 max_grad_norm=0.5 wandb_entity='nonarruginitocalamarodiferro-usi' wandb_project='pgx-minatar-ppo' save_model=False
# Finishing last run (ID:hdlfcc0k) before initializing another...
# VBox(children=(Label(value='0.017 MB of 0.017 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">dry-dawn-69</strong> at: <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/hdlfcc0k' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/hdlfcc0k</a><br/> View project at: <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241206_130835-hdlfcc0k/logs</code>
# Successfully finished last run (ID:hdlfcc0k). Initializing new run:<br/>
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241206_131118-vi647d8b</code>
# Syncing run <strong><a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/vi647d8b' target="_blank">breezy-smoke-70</a></strong> to <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo</a>
#  View run at <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/vi647d8b' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/vi647d8b</a>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 360
#     358 wandb.init(project=args.wandb_project, entity=args.wandb_entity, config=args.dict())
#     359 rng = jax.random.PRNGKey(args.seed)
# --> 360 out = train(rng)
#     361 if args.save_model:
#     362     with open(f"{args.env_name}-seed={args.seed}.ckpt", "wb") as f:
#
# Cell In[13], line 335, in train(rng)
#     333 tt += et - st
#     334 rng, _rng = jax.random.split(rng)
# --> 335 eval_R = evaluate(runner_state[0], _rng)
#     336 log = {"sec": tt, f"{args.env_name}/eval_R": float(eval_R), "steps": steps}
#     337 print(log)
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/pjit.py:298, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     296 @api_boundary
#     297 def cache_miss(*args, **kwargs):
# --> 298   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     299       jit_info, *args, **kwargs)
#     300   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     301   maybe_fastpath_data = _get_fastpath_data(
#     302       executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     303       jit_info.abstracted_axes)
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/pjit.py:176, in _python_pjit_helper(jit_info, *args, **kwargs)
#     173   args_flat = [*init_states, *args_flat]
#     175 try:
# --> 176   out_flat = pjit_p.bind(*args_flat, **params)
#     177 except pxla.DeviceAssignmentMismatchError as e:
#     178   fails, = e.args
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/core.py:2788, in AxisPrimitive.bind(self, *args, **params)
#    2784 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2785                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2786 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787              else axis_main.with_cur_sublevel())
# -> 2788 return self.bind_with_trace(top_trace, args, params)
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/core.py:425, in Primitive.bind_with_trace(self, trace, args, params)
#     424 def bind_with_trace(self, trace, args, params):
# --> 425   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/pjit.py:1488, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1485 has_explicit_sharding = _pjit_explicit_sharding(
#    1486     in_shardings, out_shardings, None, None)
#    1487 if xla_extension_version >= 226:
# -> 1488   return xc._xla.pjit(
#    1489       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1490       tree_util.dispatch_registry,
#    1491       pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type: ignore
#    1492       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1493 else:
#    1494   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1495                       tree_util.dispatch_registry,
#    1496                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/pjit.py:1471, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1470 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1471   out_flat, compiled = _pjit_call_impl_python(
#    1472       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1473       out_shardings=out_shardings, resource_env=resource_env,
#    1474       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1475       inline=inline)
#    1476   fastpath_data = _get_fastpath_data(
#    1477       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1478       None)
#    1479   return out_flat, fastpath_data
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/pjit.py:1406, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1397 global _most_recent_pjit_call_executable
#    1399 in_shardings = _resolve_in_shardings(
#    1400     args, in_shardings, out_shardings,
#    1401     resource_env.physical_mesh if resource_env is not None else None)
#    1403 compiled = _pjit_lower(
#    1404     jaxpr, in_shardings, out_shardings, resource_env,
#    1405     donated_invars, name, keep_unused, inline,
# -> 1406     lowering_parameters=mlir.LoweringParameters()).compile()
#    1407 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1408 # This check is expensive so only do it if enable_checks is on.
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2369, in MeshComputation.compile(self, compiler_options)
#    2367 def compile(self, compiler_options=None) -> MeshExecutable:
#    2368   if self._executable is None or compiler_options is not None:
# -> 2369     executable = UnloadedMeshExecutable.from_hlo(
#    2370         self._name, self._hlo, **self.compile_args,
#    2371         compiler_options=compiler_options)
#    2372     if compiler_options is None:
#    2373       self._executable = executable
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2908, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2905       mesh = i.mesh  # type: ignore
#    2906       break
# -> 2908 xla_executable, compile_options = _cached_compilation(
#    2909     hlo, name, mesh, spmd_lowering,
#    2910     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2911     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2912     compiler_options_keys, compiler_options_values)
#    2914 if hasattr(backend, "compile_replicated"):
#    2915   semantics_in_shardings = SemanticallyEqualShardings(
#    2916       in_shardings, global_in_avals)  # type: ignore
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2718, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2713   return None, compile_options
#    2715 with dispatch.log_elapsed_time(
#    2716     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2717     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2718   xla_executable = compiler.compile_or_get_cached(
#    2719       backend, computation, dev, compile_options, host_callbacks)
#    2720 return xla_executable, compile_options
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/compiler.py:333, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     323   return _compile_and_write_autotune_config(
#     324       backend,
#     325       computation,
#    (...)
#     330       cache_key,
#     331   )
#     332 else:
# --> 333   return _compile_and_write_cache(
#     334       backend,
#     335       computation,
#     336       compile_options,
#     337       host_callbacks,
#     338       module_name,
#     339       cache_key,
#     340   )
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/compiler.py:500, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     491 def _compile_and_write_cache(
#     492     backend: xc.Client,
#     493     computation: ir.Module,
#    (...)
#     497     cache_key: str,
#     498 ) -> xc.LoadedExecutable:
#     499   start_time = time.monotonic()
# --> 500   executable = backend_compile(
#     501       backend, computation, compile_options, host_callbacks
#     502   )
#     503   compile_time = time.monotonic() - start_time
#     504   _cache_write(
#     505       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     506   )
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File /opt/conda/lib/python3.10/site-packages/jax/_src/compiler.py:238, in backend_compile(backend, module, options, host_callbacks)
#     233   return backend.compile(built_c, compile_options=options,
#     234                          host_callbacks=host_callbacks)
#     235 # Some backends don't have `host_callbacks` option yet
#     236 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     237 # to take in `host_callbacks`
# --> 238 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
# Configuration class for DPO
class DPOConfig(BaseModel):
    env_name: Literal[
        "minatar-breakout",
        "minatar-freeway",
        "minatar-space_invaders",
        "minatar-asterix",
        "minatar-seaquest",
    ] = "minatar-space_invaders"
    seed: int = 2
    lr: float = 5e-4
    num_envs: int = 2048
    num_eval_envs: int = 128
    num_steps: int = 5
    total_timesteps: int = 10000000
    update_epochs: int = 4
    minibatch_size: int = 1024
    num_minibatches: int = 32
    gamma: float = 0.99
    gae_lambda: float = 0.95
    ent_coef: float = 0.01
    vf_coef: float = 0.5
    max_grad_norm: float = 8.0
    dpo_alpha: float = 8.0
    dpo_beta: float = 0.6
    wandb_entity: str = "your-wandb-entity"
    wandb_project: str = "pgx-minatar-dpo"
    save_model: bool = False

    class Config:
        extra = "forbid"

args = DPOConfig()

# Initialize the environment
env = pgx.make(str(args.env_name))

num_updates = args.total_timesteps // args.num_envs // args.num_steps
num_minibatches = args.num_envs * args.num_steps // args.minibatch_size

# Actor-Critic model definition
class ActorCritic(hk.Module):
    def __init__(self, num_actions, activation="tanh"):
        super().__init__()
        self.num_actions = num_actions
        self.activation = activation

    def __call__(self, x):
        x = x.astype(jnp.float32)
        activation = jax.nn.tanh if self.activation == "tanh" else jax.nn.relu
        x = hk.Conv2D(32, kernel_shape=2)(x)
        x = jax.nn.relu(x)
        x = hk.avg_pool(x, window_shape=(2, 2), strides=(2, 2), padding="VALID")
        x = x.reshape((x.shape[0], -1))  # Flatten
        x = hk.Linear(64)(x)
        x = jax.nn.relu(x)
        actor_mean = hk.Linear(self.num_actions)(activation(hk.Linear(64)(activation(hk.Linear(64)(x)))))
        critic = hk.Linear(1)(activation(hk.Linear(64)(activation(hk.Linear(64)(x)))))
        return actor_mean, jnp.squeeze(critic, axis=-1)

def forward_fn(x):
    net = ActorCritic(env.num_actions, activation="tanh")
    logits, value = net(x)
    return logits, value

forward = hk.without_apply_rng(hk.transform(forward_fn))

# Optimizer
optimizer = optax.chain(
    optax.clip_by_global_norm(args.max_grad_norm),
    optax.adam(args.lr, eps=1e-5)
)

# Transition class
class Transition(NamedTuple):
    done: jnp.ndarray
    action: jnp.ndarray
    value: jnp.ndarray
    reward: jnp.ndarray
    log_prob: jnp.ndarray
    obs: jnp.ndarray
    lifetime_info: jnp.ndarray  # Temporal information for TA-LPO

# Generalized Advantage Estimation
def _calculate_gae(traj_batch, last_val):
    def _get_advantages(gae_and_next_value, transition):
        gae, next_value = gae_and_next_value
        delta = transition.reward + args.gamma * next_value * (1 - transition.done) - transition.value
        gae = delta + args.gamma * args.gae_lambda * (1 - transition.done) * gae
        return (gae, transition.value), gae

    _, advantages = jax.lax.scan(
        _get_advantages,
        (jnp.zeros_like(last_val), last_val),
        traj_batch,
        reverse=True
    )
    return advantages, advantages + traj_batch.value

# Drift-based Loss Function
def _loss_fn(params, traj_batch, advantages, targets, lifetime_info):
    logits, value = forward.apply(params, traj_batch.obs)
    pi = distrax.Categorical(logits=logits)
    log_prob = pi.log_prob(traj_batch.action)

    # Critic Loss
    value_pred_clipped = traj_batch.value + (
        value - traj_batch.value
    ).clip(-args.clip_eps, args.clip_eps)
    value_losses = jnp.square(value - targets)
    value_losses_clipped = jnp.square(value_pred_clipped - targets)
    value_loss = 0.5 * jnp.maximum(value_losses, value_losses_clipped).mean()

    # Drift Function Logic
    alpha = args.dpo_alpha
    beta = args.dpo_beta
    log_diff = log_prob - traj_batch.log_prob
    ratio = jnp.exp(log_diff)
    gae = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

    # Temporal Factor for TA-LPO
    temporal_factor = lifetime_info[..., None]
    is_pos = (gae >= 0.0).astype("float32")
    drift1 = nn.relu(ratio - 1.0 - alpha * nn.tanh((ratio - 1.0) / alpha)) * temporal_factor
    drift2 = nn.relu(log_diff - beta * nn.tanh(log_diff / beta)) * (1 - temporal_factor)
    drift = drift1 * is_pos + drift2 * (1 - is_pos)
    loss_actor = -(ratio * gae - drift).mean()

    # Entropy Regularization
    entropy = pi.entropy().mean()

    # Total Loss
    total_loss = loss_actor + args.vf_coef * value_loss - args.ent_coef * entropy
    return total_loss, (value_loss, loss_actor, entropy)

def make_update_fn():
    def _update_step(runner_state):
        step_fn = jax.vmap(env.step)

        def _env_step(runner_state, unused):
            params, opt_state, env_state, last_obs, rng, step_count = runner_state

            # Calculate Lifetime Information (Temporal Awareness)
            total_steps = args.num_steps * args.num_envs
            lifetime_info = jnp.array([step_count / total_steps], dtype=jnp.float32)

            # Select Action
            rng, _rng = jax.random.split(rng)
            logits, value = forward.apply(params, last_obs)
            pi = distrax.Categorical(logits=logits)
            action = pi.sample(seed=_rng)
            log_prob = pi.log_prob(action)

            # Step Environment
            rng, _rng = jax.random.split(rng)
            keys = jax.random.split(_rng, env_state.observation.shape[0])
            env_state = step_fn(env_state, action, keys)

            # Create Transition
            transition = Transition(
                env_state.terminated,
                action,
                value,
                jnp.squeeze(env_state.rewards),
                log_prob,
                last_obs,
                lifetime_info
            )

            # Update Runner State
            runner_state = (params, opt_state, env_state, env_state.observation, rng, step_count + 1)
            return runner_state, transition

        runner_state, traj_batch = jax.lax.scan(_env_step, runner_state, None, args.num_steps)
        params, opt_state, env_state, last_obs, rng, step_count = runner_state
        _, last_val = forward.apply(params, last_obs)
        advantages, targets = _calculate_gae(traj_batch, last_val)

        def _update_epoch(update_state, unused):
            def _update_minbatch(tup, batch_info):
                params, opt_state = tup
                traj_batch, advantages, targets = batch_info

                def _loss_fn(params, traj_batch, gae, targets):
                    logits, value = forward.apply(params, traj_batch.obs)
                    pi = distrax.Categorical(logits=logits)
                    log_prob = pi.log_prob(traj_batch.action)

                    # Critic Loss
                    value_pred_clipped = traj_batch.value + (
                        value - traj_batch.value
                    ).clip(-args.clip_eps, args.clip_eps)
                    value_losses = jnp.square(value - targets)
                    value_losses_clipped = jnp.square(value_pred_clipped - targets)
                    value_loss = 0.5 * jnp.maximum(value_losses, value_losses_clipped).mean()

                    # Actor Loss with DPO
                    alpha = args.dpo_alpha
                    beta = args.dpo_beta
                    log_diff = log_prob - traj_batch.log_prob
                    ratio = jnp.exp(log_diff)
                    gae = (gae - gae.mean()) / (gae.std() + 1e-8)
                    is_pos = (gae >= 0.0).astype("float32")
                    drift1 = nn.relu(ratio - 1.0 - alpha * nn.tanh((ratio - 1.0) / alpha))
                    drift2 = nn.relu(log_diff - beta * nn.tanh(log_diff / beta))
                    drift = drift1 * is_pos + drift2 * (1 - is_pos)
                    loss_actor = -(ratio * gae - drift).mean()

                    # Entropy Regularization
                    entropy = pi.entropy().mean()

                    # Total Loss
                    total_loss = (
                        loss_actor
                        + args.vf_coef * value_loss
                        - args.ent_coef * entropy
                    )
                    return total_loss, (value_loss, loss_actor, entropy)

                grad_fn = jax.value_and_grad(_loss_fn, has_aux=True)
                total_loss, grads = grad_fn(params, traj_batch, advantages, targets)
                updates, opt_state = optimizer.update(grads, opt_state)
                params = optax.apply_updates(params, updates)
                return (params, opt_state), total_loss

            params, opt_state, traj_batch, advantages, targets, rng = update_state
            rng, _rng = jax.random.split(rng)
            batch_size = args.minibatch_size * num_minibatches
            assert batch_size == args.num_steps * args.num_envs, "Batch size mismatch."
            permutation = jax.random.permutation(_rng, batch_size)
            batch = (traj_batch, advantages, targets)
            batch = jax.tree_util.tree_map(lambda x: x.reshape((batch_size,) + x.shape[2:]), batch)
            shuffled_batch = jax.tree_util.tree_map(lambda x: jnp.take(x, permutation, axis=0), batch)
            minibatches = jax.tree_util.tree_map(
                lambda x: jnp.reshape(x, [num_minibatches, -1] + list(x.shape[1:])),
                shuffled_batch,
            )
            (params, opt_state), _ = jax.lax.scan(_update_minbatch, (params, opt_state), minibatches)
            update_state = (params, opt_state, traj_batch, advantages, targets, rng)
            return update_state, None

        update_state = (params, opt_state, traj_batch, advantages, targets, rng)
        update_state, _ = jax.lax.scan(_update_epoch, update_state, None, args.update_epochs)
        params, opt_state, _, _, _, rng = update_state
        runner_state = (params, opt_state, env_state, last_obs, rng, step_count)
        return runner_state, None

    return _update_step

@jax.jit
def evaluate(params, rng_key):
    step_fn = jax.vmap(env.step)
    rng_key, sub_key = jax.random.split(rng_key)
    subkeys = jax.random.split(sub_key, args.num_eval_envs)
    state = jax.vmap(env.init)(subkeys)
    R = jnp.zeros_like(state.rewards)

    def cond_fn(tup):
        state, _, _ = tup
        return ~state.terminated.all()

    def loop_fn(tup):
        state, R, rng_key = tup
        logits, _ = forward.apply(params, state.observation)
        pi = distrax.Categorical(logits=logits)
        rng_key, _rng = jax.random.split(rng_key)
        action = pi.sample(seed=_rng)
        rng_key, _rng = jax.random.split(rng_key)
        keys = jax.random.split(_rng, state.observation.shape[0])
        state = step_fn(state, action, keys)
        return state, R + state.rewards, rng_key

    state, R, _ = jax.lax.while_loop(cond_fn, loop_fn, (state, R, rng_key))
    return R.mean()

def train(rng):
    tt = 0
    st = time.time()

    # Initialize Network
    rng, _rng = jax.random.split(rng)
    init_x = jnp.zeros((1,) + env.observation_shape)
    params = forward.init(_rng, init_x)
    opt_state = optimizer.init(params=params)

    # Initialize Update Function
    _update_step = make_update_fn()
    jitted_update_step = jax.jit(_update_step)

    # Initialize Environment
    rng, _rng = jax.random.split(rng)
    reset_rng = jax.random.split(_rng, args.num_envs)
    env_state = jax.jit(jax.vmap(env.init))(reset_rng)

    rng, _rng = jax.random.split(rng)
    runner_state = (params, opt_state, env_state, env_state.observation, _rng)

    # Warm-Up
    _, _ = jitted_update_step(runner_state)

    steps = 0

    # Initial Evaluation
    et = time.time()  # exclude evaluation time
    tt += et - st
    rng, _rng = jax.random.split(rng)
    eval_R = evaluate(runner_state[0], _rng)
    log = {"sec": tt, f"{args.env_name}/eval_R": float(eval_R), "steps": steps}
    print(log)
    wandb.log(log)
    st = time.time()

    # Training Loop
    for i in range(num_updates):
        runner_state, loss_info = jitted_update_step(runner_state)
        steps += args.num_envs * args.num_steps

        # Evaluation
        et = time.time()  # exclude evaluation time
        tt += et - st
        rng, _rng = jax.random.split(rng)
        eval_R = evaluate(runner_state[0], _rng)
        log = {"sec": tt, f"{args.env_name}/eval_R": float(eval_R), "steps": steps}
        print(log)
        wandb.log(log)
        st = time.time()

    return runner_state

if __name__ == "__main__":
    wandb.init(project=args.wandb_project, entity=args.wandb_entity, config=args.dict())
    rng = jax.random.PRNGKey(args.seed)
    out = train(rng)
    if args.save_model:
        with open(f"{args.env_name}-seed={args.seed}.ckpt", "wb") as f:
            pickle.dump(out[0], f)
# Out:
# Finishing last run (ID:u49gt8zd) before initializing another...
# VBox(children=(Label(value='0.121 MB of 0.121 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>minatar-space_invaders/eval_R</td><td>▁▁▁▂▂▃▃▃▄▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▅▆▅▆▆▇▇▆▆▇▇███</td></tr><tr><td>sec</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▄▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>steps</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>minatar-space_invaders/eval_R</td><td>145.67188</td></tr><tr><td>sec</td><td>10.36564</td></tr><tr><td>steps</td><td>12503040</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gentle-wave-79</strong> at: <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/u49gt8zd' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/u49gt8zd</a><br/> View project at: <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241207_175252-u49gt8zd/logs</code>
# Successfully finished last run (ID:u49gt8zd). Initializing new run:<br/>
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241207_181152-124fidu0</code>
# Syncing run <strong><a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/124fidu0' target="_blank">silvery-energy-80</a></strong> to <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo</a>
#  View run at <a href='https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/124fidu0' target="_blank">https://wandb.ai/nonarruginitocalamarodiferro-usi/pgx-minatar-ppo/runs/124fidu0</a>
# {'sec': 3.587453842163086, 'minatar-space_invaders/eval_R': 4.1640625, 'steps': 0}
# {'sec': 3.5949692726135254, 'minatar-space_invaders/eval_R': 3.2734375, 'steps': 10240}
# {'sec': 3.6001315116882324, 'minatar-space_invaders/eval_R': 3.765625, 'steps': 20480}
# {'sec': 3.60487699508667, 'minatar-space_invaders/eval_R': 3.0390625, 'steps': 30720}
# {'sec': 3.6099936962127686, 'minatar-space_invaders/eval_R': 3.125, 'steps': 40960}
# {'sec': 3.614887237548828, 'minatar-space_invaders/eval_R': 3.609375, 'steps': 51200}
# {'sec': 3.6198906898498535, 'minatar-space_invaders/eval_R': 3.421875, 'steps': 61440}
# {'sec': 3.6247944831848145, 'minatar-space_invaders/eval_R': 3.6953125, 'steps': 71680}
# {'sec': 3.629664182662964, 'minatar-space_invaders/eval_R': 5.2890625, 'steps': 81920}
# {'sec': 3.6349616050720215, 'minatar-space_invaders/eval_R': 5.5859375, 'steps': 92160}
# {'sec': 3.6398162841796875, 'minatar-space_invaders/eval_R': 5.75, 'steps': 102400}
# {'sec': 3.644583225250244, 'minatar-space_invaders/eval_R': 7.3984375, 'steps': 112640}
# {'sec': 3.6494414806365967, 'minatar-space_invaders/eval_R': 6.3046875, 'steps': 122880}
# {'sec': 3.654228448867798, 'minatar-space_invaders/eval_R': 7.078125, 'steps': 133120}
# {'sec': 3.6592493057250977, 'minatar-space_invaders/eval_R': 6.171875, 'steps': 143360}
# {'sec': 3.664224863052368, 'minatar-space_invaders/eval_R': 6.5078125, 'steps': 153600}
# {'sec': 3.6692075729370117, 'minatar-space_invaders/eval_R': 5.890625, 'steps': 163840}
# {'sec': 3.6743040084838867, 'minatar-space_invaders/eval_R': 6.203125, 'steps': 174080}
# {'sec': 3.6795458793640137, 'minatar-space_invaders/eval_R': 6.8125, 'steps': 184320}
# {'sec': 3.68465518951416, 'minatar-space_invaders/eval_R': 7.4296875, 'steps': 194560}
# {'sec': 3.689788341522217, 'minatar-space_invaders/eval_R': 7.8984375, 'steps': 204800}
# {'sec': 3.6950159072875977, 'minatar-space_invaders/eval_R': 8.25, 'steps': 215040}
# {'sec': 3.7002763748168945, 'minatar-space_invaders/eval_R': 9.5078125, 'steps': 225280}
# {'sec': 3.705483913421631, 'minatar-space_invaders/eval_R': 9.171875, 'steps': 235520}
# {'sec': 3.710550546646118, 'minatar-space_invaders/eval_R': 10.109375, 'steps': 245760}
# {'sec': 3.715700387954712, 'minatar-space_invaders/eval_R': 9.9375, 'steps': 256000}
# {'sec': 3.720862865447998, 'minatar-space_invaders/eval_R': 10.75, 'steps': 266240}
# {'sec': 3.7261219024658203, 'minatar-space_invaders/eval_R': 10.421875, 'steps': 276480}
# {'sec': 3.7313339710235596, 'minatar-space_invaders/eval_R': 11.1171875, 'steps': 286720}
# {'sec': 3.736668348312378, 'minatar-space_invaders/eval_R': 12.2109375, 'steps': 296960}
# {'sec': 3.7420260906219482, 'minatar-space_invaders/eval_R': 12.1640625, 'steps': 307200}
# {'sec': 3.7472169399261475, 'minatar-space_invaders/eval_R': 12.015625, 'steps': 317440}
# {'sec': 3.752537250518799, 'minatar-space_invaders/eval_R': 13.6640625, 'steps': 327680}
# {'sec': 3.757772445678711, 'minatar-space_invaders/eval_R': 12.90625, 'steps': 337920}
# {'sec': 3.7631676197052, 'minatar-space_invaders/eval_R': 13.890625, 'steps': 348160}
# {'sec': 3.7685399055480957, 'minatar-space_invaders/eval_R': 13.6953125, 'steps': 358400}
# {'sec': 3.7739369869232178, 'minatar-space_invaders/eval_R': 14.5078125, 'steps': 368640}
# {'sec': 3.7793920040130615, 'minatar-space_invaders/eval_R': 15.359375, 'steps': 378880}
# {'sec': 3.784811019897461, 'minatar-space_invaders/eval_R': 16.1953125, 'steps': 389120}
# {'sec': 3.790188789367676, 'minatar-space_invaders/eval_R': 15.7578125, 'steps': 399360}
# {'sec': 3.796048164367676, 'minatar-space_invaders/eval_R': 18.0, 'steps': 409600}
# {'sec': 3.8016340732574463, 'minatar-space_invaders/eval_R': 16.984375, 'steps': 419840}
# {'sec': 3.807110548019409, 'minatar-space_invaders/eval_R': 17.15625, 'steps': 430080}
# {'sec': 3.8124420642852783, 'minatar-space_invaders/eval_R': 18.8984375, 'steps': 440320}
# {'sec': 3.818040370941162, 'minatar-space_invaders/eval_R': 18.7421875, 'steps': 450560}
# {'sec': 3.823554277420044, 'minatar-space_invaders/eval_R': 17.7421875, 'steps': 460800}
# {'sec': 3.829263687133789, 'minatar-space_invaders/eval_R': 22.0234375, 'steps': 471040}
# {'sec': 3.8349502086639404, 'minatar-space_invaders/eval_R': 19.125, 'steps': 481280}
# {'sec': 3.8405067920684814, 'minatar-space_invaders/eval_R': 19.2578125, 'steps': 491520}
# {'sec': 3.8463921546936035, 'minatar-space_invaders/eval_R': 20.0859375, 'steps': 501760}
# {'sec': 3.8520421981811523, 'minatar-space_invaders/eval_R': 18.8515625, 'steps': 512000}
# {'sec': 3.8576064109802246, 'minatar-space_invaders/eval_R': 18.25, 'steps': 522240}
# {'sec': 3.8632538318634033, 'minatar-space_invaders/eval_R': 19.1875, 'steps': 532480}
# {'sec': 3.8687140941619873, 'minatar-space_invaders/eval_R': 22.0546875, 'steps': 542720}
# {'sec': 3.874622106552124, 'minatar-space_invaders/eval_R': 20.8203125, 'steps': 552960}
# {'sec': 3.8801486492156982, 'minatar-space_invaders/eval_R': 22.140625, 'steps': 563200}
# {'sec': 3.885864019393921, 'minatar-space_invaders/eval_R': 21.75, 'steps': 573440}
# {'sec': 3.8914899826049805, 'minatar-space_invaders/eval_R': 20.828125, 'steps': 583680}
# {'sec': 3.8971362113952637, 'minatar-space_invaders/eval_R': 23.71875, 'steps': 593920}
# {'sec': 3.9029035568237305, 'minatar-space_invaders/eval_R': 23.984375, 'steps': 604160}
# {'sec': 3.908437728881836, 'minatar-space_invaders/eval_R': 24.4296875, 'steps': 614400}
# {'sec': 3.914267063140869, 'minatar-space_invaders/eval_R': 24.640625, 'steps': 624640}
# {'sec': 3.9200799465179443, 'minatar-space_invaders/eval_R': 21.3984375, 'steps': 634880}
# {'sec': 3.9260549545288086, 'minatar-space_invaders/eval_R': 24.2421875, 'steps': 645120}
# {'sec': 3.9319028854370117, 'minatar-space_invaders/eval_R': 24.2421875, 'steps': 655360}
# {'sec': 3.93766713142395, 'minatar-space_invaders/eval_R': 28.7421875, 'steps': 665600}
# {'sec': 3.943441390991211, 'minatar-space_invaders/eval_R': 27.484375, 'steps': 675840}
# {'sec': 3.949188232421875, 'minatar-space_invaders/eval_R': 28.7578125, 'steps': 686080}
# {'sec': 3.9549636840820312, 'minatar-space_invaders/eval_R': 28.265625, 'steps': 696320}
# {'sec': 3.9606146812438965, 'minatar-space_invaders/eval_R': 29.234375, 'steps': 706560}
# {'sec': 3.9661550521850586, 'minatar-space_invaders/eval_R': 28.96875, 'steps': 716800}
# {'sec': 3.971781015396118, 'minatar-space_invaders/eval_R': 27.4375, 'steps': 727040}
# {'sec': 3.9774014949798584, 'minatar-space_invaders/eval_R': 26.71875, 'steps': 737280}
# {'sec': 3.9829530715942383, 'minatar-space_invaders/eval_R': 28.8828125, 'steps': 747520}
# {'sec': 3.988985061645508, 'minatar-space_invaders/eval_R': 27.7265625, 'steps': 757760}
